# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks=pd.read_csv('tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
#to check the null values in the dataset
print(pd.isnull(df_tracks).sum())
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB

# %%
#sort the df otbo popularity column
sorted_df_pop=df_tracks.sort_values("popularity",ascending=True)
sorted_df_pop
# Out:
#                             id                                          name  \
# 546130  181rTRhCcggZPwP2TUcVqm  Newspaper Reports On Abner, 20 February 1935
# 546222  0yOCz3V5KMm8l1T8EFc60i                                        恋は水の上で
# 546221  0y48Hhwe52099UqYjegRCO                                         私の誕生日
# 546220  0xCmgtf9ka07hkZg3D6PaV                           エル・チョクロ (EL CHOCLO)
# 546219  0tBXS3VuCPX7KWUFH2nros                                      恋は不思議なもの
# ...                        ...                                           ...
# 92811   6tDDoYIxWvMLTdKpjFkc1B                                     telepatía
# 92810   5QO79kh1waicV47BqGRL3g                               Save Your Tears
# 93804   3Ofmpyhv5UAQ70mENzB277                        Astronaut In The Ocean
# 93803   7lPN2DXiMsVn7XUKtOW1CS                               drivers license
# 93802   4iJyoBOLtHqaGxP12qzhQI        Peaches (feat. Daniel Caesar & Giveon)
#
#         popularity  duration_ms  explicit  \
# 546130           0       896575         0
# 546222           0       188440         0
# 546221           0       173467         0
# 546220           0       205280         0
# 546219           0       185733         0
# ...            ...          ...       ...
# 92811           97       160191         0
# 92810           97       215627         1
# 93804           98       132780         0
# 93803           99       242014         1
# 93802          100       198082         1
#
#                                                   artists  \
# 546130  ['Norris Goff', 'Chester Lauck', 'Carlton Bric...
# 546222                                  ['Hibari Misora']
# 546221                                  ['Hibari Misora']
# 546220                                  ['Hibari Misora']
# 546219                                  ['Hibari Misora']
# ...                                                   ...
# 92811                                      ['Kali Uchis']
# 92810                                      ['The Weeknd']
# 93804                                     ['Masked Wolf']
# 93803                                  ['Olivia Rodrigo']
# 93802        ['Justin Bieber', 'Daniel Caesar', 'Giveon']
#
#                                                id_artists release_date  \
# 546130  ['3WCwCPDMpGzrt0Qz6quumy', '7vk8UqABg0Sga78GI3...   1935-02-20
# 546222                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546221                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546220                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546219                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# ...                                                   ...          ...
# 92811                          ['1U1el3k54VvEUzo3ybLPlM']   2020-12-04
# 92810                          ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 93804                          ['1uU7g3DNSbsu0QjSEqZtEd']   2021-01-06
# 93803                          ['1McMsnEElThX1knmY4oliG']   2021-01-08
# 93802   ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 546130         0.595   0.262    8   -17.746     1       0.9320        0.9930
# 546222         0.418   0.388    0    -8.580     1       0.0358        0.9250
# 546221         0.642   0.178    5   -11.700     1       0.0501        0.9930
# 546220         0.695   0.467    0   -12.236     0       0.0422        0.8270
# 546219         0.389   0.388    2    -8.221     1       0.0351        0.8690
# ...              ...     ...  ...       ...   ...          ...           ...
# 92811          0.653   0.524   11    -9.016     0       0.0502        0.1120
# 92810          0.680   0.826    0    -5.487     1       0.0309        0.0212
# 93804          0.778   0.695    4    -6.865     0       0.0913        0.1750
# 93803          0.585   0.436   10    -8.761     1       0.0601        0.7210
# 93802          0.677   0.696    0    -6.181     1       0.1190        0.3210
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 546130          0.007510    0.0991    0.320   79.849               4
# 546222          0.000014    0.1050    0.439   94.549               4
# 546221          0.000943    0.0928    0.715  119.013               4
# 546220          0.000000    0.0861    0.756  125.941               4
# 546219          0.000000    0.0924    0.372   72.800               4
# ...                  ...       ...      ...      ...             ...
# 92811           0.000000    0.2030    0.553   83.970               4
# 92810           0.000012    0.5430    0.644  118.051               4
# 93804           0.000000    0.1500    0.472  149.996               4
# 93803           0.000013    0.1050    0.132  143.874               4
# 93802           0.000000    0.4200    0.464   90.030               4
#
# [586672 rows x 20 columns]

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# liveness          586672.0       0.213935       0.184326     0.0       0.0983
# valence           586672.0       0.552292       0.257671     0.0       0.3460
# tempo             586672.0     118.464857      29.764108     0.0      95.6000
# time_signature    586672.0       3.873382       0.473162     0.0       4.0000
#
#                             50%           75%          max
# popularity            27.000000      41.00000      100.000
# duration_ms       214893.000000  263867.00000  5621218.000
# explicit               0.000000       0.00000        1.000
# danceability           0.577000       0.68600        0.991
# energy                 0.549000       0.74800        1.000
# key                    5.000000       8.00000       11.000
# loudness              -9.243000      -6.48200        5.376
# mode                   1.000000       1.00000        1.000
# speechiness            0.044300       0.07630        0.971
# acousticness           0.422000       0.78500        0.996
# instrumentalness       0.000024       0.00955        1.000
# liveness               0.139000       0.27800        1.000
# valence                0.564000       0.76900        1.000
# tempo                117.384000     136.32100      246.381
# time_signature         4.000000       4.00000        5.000

# %% [markdown]
# # Top 10 most popular songs on spotify

# %%
most_popular=df_tracks.query('popularity>90',inplace=False ).sort_values('popularity',ascending=False)
#inplace = False means we are not making changes to the original df
most_popular.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
# 92813          96       200040         0
# 93805          96       242096         0
# 92814          95       164000         0
# 91866          94       226987         1
# 92816          94       198371         0
#
#                                               artists  \
# 93802    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                              ['Olivia Rodrigo']
# 93804                                 ['Masked Wolf']
# 92810                                  ['The Weeknd']
# 92811                                  ['Kali Uchis']
# 92813                                  ['The Weeknd']
# 93805  ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 92814                                      ['Tiësto']
# 91866                                    ['Doja Cat']
# 92816                                      ['Giveon']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
# 93803                         ['1McMsnEElThX1knmY4oliG']   2021-01-08
# 93804                         ['1uU7g3DNSbsu0QjSEqZtEd']   2021-01-06
# 92810                         ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 92811                         ['1U1el3k54VvEUzo3ybLPlM']   2020-12-04
# 92813                         ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 93805  ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...   2021-03-05
# 92814                         ['2o5jDhtHVPhrJdv3cEQ99Z']   2020-09-16
# 91866                         ['5cj0lLjcoR7YOSnhnX0Po5']   2019-11-07
# 92816                         ['4fxd5Ee7UefO4CUXgwJ7IP']   2020-03-27
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 93802         0.677   0.696    0    -6.181     1       0.1190       0.32100
# 93803         0.585   0.436   10    -8.761     1       0.0601       0.72100
# 93804         0.778   0.695    4    -6.865     0       0.0913       0.17500
# 92810         0.680   0.826    0    -5.487     1       0.0309       0.02120
# 92811         0.653   0.524   11    -9.016     0       0.0502       0.11200
# 92813         0.514   0.730    1    -5.934     1       0.0598       0.00146
# 93805         0.586   0.616    5    -7.964     1       0.0324       0.18200
# 92814         0.798   0.620    8    -7.079     0       0.2320       0.41400
# 91866         0.749   0.463   11    -8.433     1       0.0828       0.20800
# 92816         0.449   0.465    0    -8.964     1       0.0791       0.52400
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 93802          0.000000    0.4200    0.464   90.030               4
# 93803          0.000013    0.1050    0.132  143.874               4
# 93804          0.000000    0.1500    0.472  149.996               4
# 92810          0.000012    0.5430    0.644  118.051               4
# 92811          0.000000    0.2030    0.553   83.970               4
# 92813          0.000095    0.0897    0.334  171.005               4
# 93805          0.000000    0.0927    0.719  148.088               4
# 92814          0.019200    0.1120    0.235  120.031               4
# 91866          0.037100    0.3370    0.190   90.028               4
# 92816          0.000001    0.3030    0.543   89.087               3

# %%
#set the release date column as the index of the dataframe
df_tracks.set_index('release_date',inplace=True)
df_tracks.index=pd.to_datetime(df_tracks.index)#yyyy-mm-dd
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450    0   -13.338
# 1922-06-01    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630    0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770    1   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946    7   -27.961
# 1922-01-01    ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580    3   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22       1       0.4510         0.674            0.7440     0.151
# 1922-06-01       1       0.9570         0.797            0.0000     0.148
# 1922-03-21       1       0.0512         0.994            0.0218     0.212
# 1922-03-21       1       0.0504         0.995            0.9180     0.104
# 1922-01-01       0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature
# release_date
# 1922-02-22      0.127  104.851               3
# 1922-06-01      0.655  102.009               1
# 1922-03-21      0.457  130.418               5
# 1922-03-21      0.397  169.980               3
# 1922-01-01      0.196  103.220               4

# %%
#find the artists that released songs on 1922-01-01
df_tracks[["artists"]].loc['1922-01-01']
# Out:
#                                                         artists
# release_date
# 1922-01-01                                      ['Dick Haymes']
# 1922-01-01                                      ['Dick Haymes']
# 1922-01-01                                    ['Francis Marty']
# 1922-01-01                                      ['Mistinguett']
# 1922-01-01                                      ['Greg Fieler']
# ...                                                         ...
# 1922-01-01               ['Abe Lyman’s Orchestra', 'Abe Lyman']
# 1922-01-01               ['Abe Lyman’s Orchestra', 'Abe Lyman']
# 1922-01-01    ['Paul Whiteman & His Orchestra', 'Paul Whitem...
# 1922-01-01               ['Abe Lyman’s Orchestra', 'Abe Lyman']
# 1922-01-01               ['Abe Lyman’s Orchestra', 'Abe Lyman']
#
# [156 rows x 1 columns]

# %%
df_tracks['duration']=df_tracks['duration_ms'].apply(lambda x:(round(x/1000))/60)
df_tracks.drop('duration_ms',inplace=True,axis=1)

# %%
df_tracks.duration.head()
# Out:
# release_date
# 1922-02-22    2.116667
# 1922-06-01    1.633333
# 1922-03-21    3.033333
# 1922-03-21    2.950000
# 1922-01-01    2.716667
# Name: duration, dtype: float64

# %%
corr_df=df_tracks.drop(['key','mode','explicit'],axis=1).corr(method='pearson')
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt='.1g',vmin=-1,vmax=1,center=0,cmap='viridis',linewidths=1,linecolor='Black')
heatmap.set_title('Correlation Heatmap Between Variable')
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
plt.show()

# %%
sample_df=df_tracks.sample(int(0.004*len(df_tracks)))
print('Length of the sample_df=',len(sample_df))
sample_df
# Out:
# Length of the sample_df= 2346
#                                   id                                    name  \
# release_date
# 1955-01-01    5eMlxAFdBKX14UcIKFmafh                              Dve Gitari
# 1974-01-01    65iQo6Dbxbp1ZJ8QuXDnJY                   Bodenstown Churchyard
# 2001-11-22    4LTIo1eXLfaBEBwIsBi2Mw  I Andledning af Beate Og Leons Bryllup
# 1973-01-01    6c3d7ofF9UNFpVq6SxHwC1                   Un amico - Remastered
# 1924-01-01    51jylcWvL25n9J6tcPFdMu            Chapter 214 - The Unlit Lamp
# ...                              ...                                     ...
# 1990-09-01    02HqwkUZsvFgfTq2tg6qfs                         En Vandringsman
# 2019-11-29    4qZZMdhN8vtk1jq2pWWgZR                            We Fell Dead
# 1964-01-20    761hnTr0o2gQm1ABf1xOmF                          Paris canaille
# 2014-06-13    17yV3hBEsxrcuhDpkxPZFG                              Karmoškale
# 2014-02-04    6PwvZQQgZxOItzN2jzaHE3                   Too Many Years (Live)
#
#               popularity  explicit  \
# release_date
# 1955-01-01             6         0
# 1974-01-01            14         0
# 2001-11-22            23         0
# 1973-01-01            37         0
# 1924-01-01             0         0
# ...                  ...       ...
# 1990-09-01            17         0
# 2019-11-29             0         0
# 1964-01-20            20         0
# 2014-06-13            17         0
# 2014-02-04             0         0
#
#                                                         artists  \
# release_date
# 1955-01-01                                   ['Theodore Bikel']
# 1974-01-01                                      ['Wolfe Tones']
# 2001-11-22    ['Hva Snakker Du Om?', 'Anders Matthesen', 'Bo...
# 1973-01-01                                  ['Ennio Morricone']
# 1924-01-01    ['Radclyffe Hall', 'Alice White', 'Synthesized...
# ...                                                         ...
# 1990-09-01                                       ['Mora Träsk']
# 2019-11-29                                   ['The Monolators']
# 1964-01-20                                     ['Yves Montand']
# 2014-06-13                                            ['Zetod']
# 2014-02-04                                   ['Jorma Kaukonen']
#
#                                                      id_artists  danceability  \
# release_date
# 1955-01-01                           ['67p0NB8haJlULQy2gr4iKZ']         0.459
# 1974-01-01                           ['3r3LPqQbhm7BKQy4LV4WfT']         0.479
# 2001-11-22    ['6cD6zHzod1pg68dRitjQDU', '7ywx4levGzk6v90WXQ...         0.490
# 1973-01-01                           ['1nIUhcKHnK6iyumRyoV68C']         0.199
# 1924-01-01    ['2OJEUmIIPsTAUjil4dOz70', '35AgMyuKAQIoMJZEp3...         0.639
# ...                                                         ...           ...
# 1990-09-01                           ['4brCOY5t3EebZpmZGsZ7JC']         0.854
# 2019-11-29                           ['2UkEjXNaqtey9Wf2R1prPO']         0.425
# 1964-01-20                           ['5ru2x3pjrNn67D22BRwlFP']         0.531
# 2014-06-13                           ['2NitYjQIt9BHYH7K4Rj5YQ']         0.476
# 2014-02-04                           ['55CXG5KDJpRYwBopfYAJHa']         0.500
#
#               energy  key  loudness  mode  speechiness  acousticness  \
# release_date
# 1955-01-01     0.197    4   -18.253     0       0.1000        0.5440
# 1974-01-01     0.137    0   -17.054     1       0.0314        0.7490
# 2001-11-22     0.323    5    -5.646     1       0.0439        0.2980
# 1973-01-01     0.750    7    -2.733     1       0.0340        0.0826
# 1924-01-01     0.276    3   -16.302     1       0.9480        0.7320
# ...              ...  ...       ...   ...          ...           ...
# 1990-09-01     0.850    7    -9.751     1       0.0785        0.1380
# 2019-11-29     0.830    7    -6.510     1       0.0473        0.0351
# 1964-01-20     0.525    7   -11.688     1       0.0621        0.6100
# 2014-06-13     0.675    6    -6.614     0       0.0415        0.6090
# 2014-02-04     0.443    9   -16.684     1       0.0455        0.8850
#
#               instrumentalness  liveness  valence    tempo  time_signature  \
# release_date
# 1955-01-01               0.000    0.1860    0.529  118.661               4
# 1974-01-01               0.000    0.1750    0.556   92.577               3
# 2001-11-22               0.000    0.2100    0.663   81.061               4
# 1973-01-01               0.857    0.3390    0.435  142.722               4
# 1924-01-01               0.000    0.1550    0.429  164.932               5
# ...                        ...       ...      ...      ...             ...
# 1990-09-01               0.000    0.0212    0.967  125.020               4
# 2019-11-29               0.481    0.1890    0.605  163.721               4
# 1964-01-20               0.000    0.4560    0.674  142.702               4
# 2014-06-13               0.133    0.1210    0.937  115.213               4
# 2014-02-04               0.193    0.9700    0.562  105.614               4
#
#               duration
# release_date
# 1955-01-01    4.500000
# 1974-01-01    3.933333
# 2001-11-22    2.616667
# 1973-01-01    2.616667
# 1924-01-01    3.966667
# ...                ...
# 1990-09-01    2.616667
# 2019-11-29    2.683333
# 1964-01-20    3.200000
# 2014-06-13    3.583333
# 2014-02-04    4.566667
#
# [2346 rows x 19 columns]

# %%
#Plot Regression map between Loudness & Energy
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y='loudness',x='energy',color='c').set(title='Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %% [markdown]
# The above graph denotes that the energy and loudness of the songs on Spotify are positively and strongly correlated.

# %%
#plot regression map between popularity and acousticness 
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y='popularity',x='acousticness',color='b').set(title='Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %% [markdown]
# The above graph denotes that Popularity and Acousticness of songs on Spotify are negatively and weakly correlated.

# %%
#Create a new column called 'dates' in the df_tracks
df_tracks['dates']=df_tracks.index.get_level_values('release_date')
df_tracks.dates=pd.to_datetime(df_tracks.dates)
years=df_tracks.dates.dt.year #extract years from the dates

# %%
pip install --user seaborn==0.11.0
# Out:
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      -------------------------------------- 283.1/283.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in c:\users\20100\anaconda3\lib\site-packages (from seaborn==0.11.0) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\20100\anaconda3\lib\site-packages (from seaborn==0.11.0) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\20100\anaconda3\lib\site-packages (from seaborn==0.11.0) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\20100\anaconda3\lib\site-packages (from seaborn==0.11.0) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20100\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20100\anaconda3\lib\site-packages (from pandas>=0.23->seaborn==0.11.0) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\20100\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.0) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#plot the distribution of total no. of songs in each year since 1922 on spotify
sns.displot(years,discrete=True,aspect=2,height=5,kind='hist').set(title='Number of songs per year')

# %%
total_dr=df_tracks.duration
fig_dims=(18,7)
fig,ax=plt.subplots(figsize=fig_dims)
fig=sns.barplot(x=years,y=total_dr,ax=ax,errwidth=False).set(title='Year vs Duration')
plt.xticks(rotation=90)
plt.show()

# %%
total_dr=df_tracks.duration
sns.set_style(style='whitegrid')
fig_dims=(10,5)
fig,ax=plt.subplots(figsize=fig_dims)
fig=sns.lineplot(x=years,y=total_dr,ax=ax).set(title='Year Vs Duration')
plt.xticks(rotation=60)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_genre=pd.read_csv('SpotifyFeatures.csv')

# %%
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
Popular_genre=df_genre[['genre', 'popularity']].sort_values(by="popularity",ascending=False)
Popular_genre=Popular_genre.drop_duplicates(subset = "popularity")
#Popular_genre=Popular_genre.head(25)
Popular_genre
# Out:
#                    genre  popularity
# 9027               Dance         100
# 86951                Rap          99
# 66643            Hip-Hop          98
# 107829               Pop          97
# 107851               Pop          96
# ...                  ...         ...
# 82389              Opera           4
# 105941             Opera           3
# 73135   Children's Music           2
# 74533   Children's Music           1
# 58202              Opera           0
#
# [101 rows x 2 columns]

# %%
plt.title('Popularity of the Songs in Different Genres')
sns.color_palette('rocket',as_cmap=True)
plt.figure(figsize=(15,8))
sns.barplot(y='genre',x='popularity',data=Popular_genre,ci=None)
plt.xlabel('Popularity')
plt.ylabel('Genre')
plt.show()

# %%
plt.title('Popularity of the Songs in Different Genres')
sns.color_palette('rocket',as_cmap=True)
sns.barplot(y='genre',x='popularity',data=df_genre,order=df_genre.sort_values('popularity').genre)
plt.xlabel('Popularity')
plt.ylabel('Genre')

# %%
sns.set_style(style='darkgrid')
plt.figure(figsize=(10,5))
famous=df_genre.sort_values('popularity',ascending=False).head(10)
sns.barplot(y='genre',x='popularity',data=famous).set(title='Top 5 Genres by popularity')

# %%
df_genre.sort_values('popularity').genre
